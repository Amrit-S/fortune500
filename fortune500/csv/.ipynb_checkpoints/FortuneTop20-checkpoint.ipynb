# %%
import pandas as pd
import cpi as cpi
from iexfinance.stocks import Stock
import difflib
import requests
import bs4
from bs4 import BeautifulSoup

# %%
cpi.update()

# %%
#Creates a new Dataframe to hold revenues for the top X amount of companies each year
def createNewDF(rangeTop):
    column_values = ['year']

    for i in range(1, rangeTop + 1):
        column_values.append('#' + str(i) + ' Revenue')
        column_values.append('#' + str(i) + ' Company')
        column_values.append('#' + str(i) + ' isTech')
        column_values.append('#' + str(i) + ' State')
    
    df_raw_revenue = pd.DataFrame(columns=column_values)
    df_raw_revenue.set_index('year', inplace=True)
    return df_raw_revenue

# %%
#Given name of the company, extracts its corresponding sector using a CSV file
def getCompanyInfoUsingCSV(company, df_company_info, yearStr, rank):
    dict_states = getDictStates()
    try:
        best_match = difflib.get_close_matches(company, df_company_info['Security'], cutoff=0.7)[0]
        print("Matched: " + company + " to " + best_match + "(" + yearStr + " #" + rank +  ")" )
    except:
        print("Could not be matched: " + company + "(" + yearStr + " #" + rank +  ")" )
        return None, None
    index = df_company_info[df_company_info['Security'] == best_match].index.tolist()[0]
    state_abr = dict_states[df_company_info.loc[index]['Headquarters Location'].split(',')[-1].strip()]
    return df_company_info.loc[index]['GICS Sector'], state_abr

#Given name of company, extracts its corresponding sector by webscraping its Fortune 500 page
def getCompanySectorUsingWebscraping(company, year, rank):
    if year < 2015:
        return
    url = "https://fortune.com/fortune500/" + str(year) + "/" + company + "/"
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    try:
        container = soup.body.table.findAll("td", {"class": "dataTable__value--3n5tL dataTable__valueAlignLeft--3uvNx"})
        sector = container[2].div.string
        print("Matched: " + company + " to " + sector)
    except:
        print("Could not be matched: " + company + "(" + str(year) + " #" + rank +  ")" )
        return
    return sector

def checkForTechnologySector(sector):
    #Check sector Technology
    return sector == "Technology"

def checkForInformationTechnologySector(sector):
    if sector == None:
        return None
    #Check sector Technology
    return sector == "Information Technology"

# %%
def getDictStates(): 
    dict_states = {
            'Alaska': 'AK',
            'Alabama':'AL',
            'Arkansas': 'AR',
            'American Samoa': 'AS',
            'Arizona': 'AZ',
            'California': 'CA',
            'Colorado' : 'CO',
            'Connecticut': 'CT',
            'District of Columbia': 'DC',
            'Delaware': 'DE',
            'Florida': 'FL',
            'Georgia': 'GA',
            'Guam': 'GU',
            'Hawaii': 'HI',
            'Iowa': 'IA',
            'Idaho' : 'ID',
            'Illinois': 'IL',
            'Indiana' : 'IN',
            'Kansas': 'KS',
            'Kentucky' : 'KY',
            'Louisiana': 'LA',
            'Massachusetts': 'MA',
            'Maryland': 'MD',
            'Maine': 'ME',
            'Michigan': 'MI',
            'Minnesota': 'MN',
            'Missouri': 'MO',
            'Northern Mariana Islands': 'MP',
            'Mississippi': 'MS',
            'Montana': 'MT',
            'National': 'NA',
            'North Carolina': 'NC',
            'North Dakota': 'ND',
            'Nebraska':'NE',
            'New Hampshire': 'NH',
            'New Jersey': 'NJ',
             'New Mexico': 'NM',
             'Nevada': 'NV',
             'New York': 'NY',
             'Ohio':'OH',
             'Oklahoma':'OK',
             'Oregon':'OR',
             'Pennsylvania':'PA',
             'Puerto Rico': 'PR',
             'Rhode Island': 'RI',
             'South Carolina': 'SC',
             'South Dakota': 'SD',
             'Tennessee': 'TN',
             'Texas': 'TX',
             'Utah': 'UT',
             'Virginia': 'VA',
             'Virgin Islands': 'VI',
             'Vermont':'VT',
             'Washington': 'WA',
             'Wisconsin' : 'WI',
             'West Virginia': 'WV',
             'Wyoming': 'WY'
    }
    return dict_states

def getStates():
    states_abr = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
              "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
              "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
              "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
              "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
    return states_abr

# %%
#All revenues's values account whether they are in Information Technology sector
#Negative values mean they are in Technology Sector
#Positive values mean they are not in Technology Sector
def populateRawDF(df, startYear, endYear, rangeTop):
    company_info = pd.read_csv('S&P500-Condensed.csv')
    for year in range(startYear,endYear + 1):
        print("-----------------------" + str(year) + "-----------------------")
        temp = pd.read_csv('fortune500-'+ str(year) + '.csv')
        temp = temp.head(rangeTop)
        
        revenues_list = list(temp['revenue ($ millions)'])
        
        for index in range(rangeTop):
            
            company = temp.loc[index]['company']
            sector, state_abr = getCompanyInfoUsingCSV(company, company_info, str(year), str(index + 1))
            is_information_sector = checkForInformationTechnologySector(sector)
                  
            #company = temp.loc[index]['company']
            #sector = getCompanySector(company, year, str(index))
            #is_information_sector = checkForTechnologySector(sector)
            
            inflated_revenue = inflateRevenue(revenues_list[index], year)
            df.set_value(year, '#' + str(index + 1) + ' Revenue', inflated_revenue)
            
            df.set_value(year, '#' + str(index + 1) + ' Company', company)
            
            #All companies that are Information Technology are marked as negative 
            df.set_value(year, '#' + str(index + 1) + ' isTech', is_information_sector)
            
            df.set_value(year, '#' + str(index + 1) + ' State', state_abr)

# %%
#Accounts for inflation of all revenues (standarizes to 2019)
def inflateDF(df, startYear, endYear, rangeTop):
    for year in range(startYear, endYear + 1):
        for col in range(rangeTop):
            #inflated to November 2019 US dollar equivalent 
            df_raw_revenue.loc[year][col] = cpi.inflate(df_raw_revenue.loc[year][col], year) 

#Accounts for inflation of all revenues (standarizes to 2019)
def inflateRevenue(revenue, year):
        return cpi.inflate(revenue, year)

# %%
#sorts through given list, returning mean of all negative & positive values
def sortThroughRow(rowList):
    negSum = 0
    posSum = 0
    for value in rowList:
        if value < 0:
            negSum += value
        else:
            posSum += value
    negSum /= len(rowList)
    posSum /= len(rowList)
    return (negSum * -1, posSum)

#calculates mean revenues for df in terms of Information Tech vs non-Information Tech
def calculateMeansForDF(df, startYear, endYear):
    negativeList = []
    positiveList = []
    for year in range(startYear, endYear + 1):
        
        result = sortThroughRow(list(df.loc[year]))
        
        negativeList.append(result[0])
        positiveList.append(result[1])
        
    df['Mean Revenue Information Technology ($ millions)'] = negativeList;
    df['Mean Revenue Not Information Technology ($ millions)'] = positiveList;

# %%
top_x_companies = 100
start_year = 2011
#inclusive
end_year = 2018

csv_suffix = str(top_x_companies) + '_' + str(start_year) + '-' + str(end_year) + '.csv'

# %%
df_raw_revenue = createNewDF(top_x_companies)
populateRawDF(df_raw_revenue, start_year, end_year, top_x_companies)
#df_raw_revenue.to_csv('raw_revenue_2000-2018.csv')
df_raw_revenue.head(20)
# Out:
# -----------------------2011-----------------------
# Could not be matched: Wal-Mart Stores(2011 #1)
# Matched: Exxon Mobil to Exxon Mobil Corp.(

# Matched: Delta Air Lines to Delta Air Lines Inc.(2012 #83)
# Could not be matched: Liberty Mutual Insurance Group(2012 #84)
# Could not be matched: World Fuel Services(2012 #85)
# Could not be matched: New York Life Insurance(2012 #86)
# Could not be matched: Plains All American Pipeline(2012 #87)
# Could not be matched: TIAA-CREF(2012 #88)
# Could not be matched: Aetna(2012 #89)
# Could not be matched: Sprint Nextel(2012 #90)
# Matched: News Corp. to Loews Corp.(2012 #91)
# Matched: General Dynamics to General Dynamics(2012 #92)
# Matched: Allstate to Allstate Corp(2012 #93)
# Matched: HCA Holdings to Capri Holdings(2012 #94)
# Matched: American Express to American Express Co(2012 #95)
# Matched: Tyson Foods to Tyson Foods(2012 #96)
# Could not be matched: Deere(2012 #97)
# Could not be matched: Murphy Oil(2012 #98)
# Matched: Philip Morris International to Philip Morris International(2012 #99)
# Could not be matched: Nationwide(2012 #100)
# -----------------------2013-----------------------
# Could not be matched: Wal-Mart Stores(2013 #1)
# Matched: Exxon Mobil to Exxon Mobil Corp.(2013 #2)
# Matched: Chevron to Chevron Corp.(2013 #3)
# Matched: Phillips 66 to Phillips 66(2013 #4)
# Matched: Berkshire Hathaway to Berkshire Hathaway(2013 #5)
# Could not be matched: Apple(2013 #6)
# Matched: General Motors to General Motors(2013 #7)
# Matched: General Electric to General Electric(2013 #8)
# Matched: Valero Energy to Valero Energy(2013 #9)
# Matched: Ford Motor to Ford Motor(2013 #10)
# Could not be matched: AT&T(2013 #11)
# Could not be matched: Fannie Mae(2013 #12)
# Could not be matched: CVS Caremark(2013 #13)
# Matched: McKesson to McKesson Corp.(2013 #14)
# Could not be matched: Hewlett-Packard(2013 #15)
# Matched: Verizon Communications to Verizon Communications(2013 #16)
# Matched: UnitedHealth Group to United Health Group Inc.(2013 #17)
# Matched: J.P. Morgan Chase & Co. to JPMorgan Chase & Co.(2013 #18)
# Matched: Cardinal Health to Cardinal Health Inc.(2013 #19)
# Matched: International Business Machines to International Business Machines(2013 #20)
# Matched: Bank of America Corp. to Bank of America Corp(2013 #21)
# Matched: Costco Wholesale to Costco Wholesale Corp.(2013 #22)
# Matched: Kroger to Kroger Co.(2013 #23)
# Could not be matched: Express Scripts Holding(2013 #24)
# Matched: Wells Fargo to Wells Fargo(2013 #25)
# Matched: Citigroup to Citigroup Inc.(2013 #26)
# Matched: Archer Daniels Midland to Archer-Daniels-Midland Co(2013 #27)
# Matched: Procter & Gamble to Procter & Gamble(2013 #28)
# Matched: Prudential Financial to Prudential Financial(2013 #29)
# Could not be matched: Boeing(2013 #30)
# Could not be matched: Freddie Mac(2013 #31)
# Matched: AmerisourceBergen to AmerisourceBergen Corp(2013 #32)
# Matched: Marathon Petroleum to Marathon Petroleum(2013 #33)
# Matched: Home Depot to Home Depot(2013 #34)
# Matched: Microsoft to Microsoft Corp.(2013 #35)
# Could not be matched: Target(2013 #36)
# Could not be matched: Walgreen(2013 #37)
# Matched: American International Group to American International Group(2013 #38)
# Could not be matched: INTL FCStone(2013 #39)
# Matched: MetLife to MetLife Inc.(2013 #40)
# Matched: Johnson & Johnson to Johnson & Johnson(2013 #41)
# Matched: Caterpillar to Caterpillar Inc.(2013 #42)
# Matched: PepsiCo to PepsiCo Inc.(2013 #43)
# Could not be matched: State Farm Insurance Cos.(2013 #44)
# Matched: ConocoPhillips to ConocoPhillips(2013 #45)
# Matched: Comcast to Comcast Corp.(2013 #46)
# Could not be matched: WellPoint(2013 #47)
# Matched: Pfizer to Pfizer Inc.(2013 #48)
# Matched: Amazon.com to Amazon.com Inc.(2013 #49)
# Matched: United Technologies to United Technologies(2013 #50)
# Could not be matched: Dell(2013 #51)
# Could not be matched: Dow Chemical(2013 #52)
# Matched: United Parcel Service to United Parcel Service(2013 #53)
# Matched: Intel to Incyte(2013 #54)
# Could not be matched: Google(2013 #55)
# Matched: Lowe's to Lowe's Cos.(2013 #56)
# Could not be matched: Coca-Cola(2013 #57)
# Could not be matched: Merck(2013 #58)
# Matched: Lockheed Martin to Lockheed Martin Corp.(2013 #59)
# Matched: Cisco Systems to Cisco Systems(2013 #60)
# Could not be matched: Best Buy(2013 #61)
# Could not be matched: Safeway(2013 #62)
# Could not be matched: FedEx(2013 #63)
# Could not be matched: Enterprise Products Partners(2013 #64)
# Could not be matched: Sysco(2013 #65)
# Could not be matched: Walt Disney(2013 #66)
# Could not be matched: Johnson Controls(2013 #67)
# Matched: Goldman Sachs Group to Goldman Sachs Group(2013 #68)
# Could not be matched: CHS(2013 #69)
# Matched: Abbott Laboratories to Abbott Laboratories(2013 #70)
# Matched: Sears Holdings to Capri Holdings(2013 #71)
# Could not be matched: DuPont(2013 #72)
# Matched: Humana to Humana Inc.(2013 #73)
# Could not be matched: World Fuel Services(2013 #74)
# Could not be matched: Hess(2013 #75)
# Could not be matched: Ingram Micro(2013 #76)
# Could not be matched: Plains All American Pipeline(2013 #77)
# Matched: Honeywell International to Mondelez International(2013 #78)
# Matched: United Continental Holdings to United Airlines Holdings(2013 #79)
# Could not be matched: Oracle(2013 #80)
# Could not be matched: Liberty Mutual Insurance Group(2013 #81)
# Matched: HCA Holdings to Capri Holdings(2013 #82)
# Matched: Delta Air Lines to Delta Air Lines Inc.(2013 #83)
# Could not be matched: Aetna(2013 #84)
# Could not be matched: Deere(2013 #85)
# Could not be matched: Supervalu(2013 #86)
# Could not be matched: Sprint Nextel(2013 #87)
# Matched: Mondelēz International to Mondelez International(2013 #88)
# Could not be matched: New York Life Insurance(2013 #89)
# Matched: American Express to American Express Co(2013 #90)
# Matched: News Corp. to Loews Corp.(2013 #91)
# Matched: Allstate to Allstate Corp(2013 #92)
# Matched: Tyson Foods to Tyson Foods(2013 #93)
# Could not be matched: Massachusetts Mutual Life Insurance(2013 #94)
# Could not be matched: Tesoro(2013 #95)
# Matched: Morgan Stanley to Morgan Stanley(2013 #96)
# Could not be matched: TIAA-CREF(2013 #97)
# Matched: General Dynamics to General Dynamics(2013 #98)
# Matched: Philip Morris International to Philip Morris International(2013 #99)
# Could not be matched: Nationwide(2013 #100)
# -----------------------2014-----------------------
# Could not be matched: Wal-Mart Stores(2014 #1)
# Matched: Exxon Mobil to Exxon Mobil Corp.(2014 #2)
# Matched: Chevron to Chevron Corp.(2014 #3)
# Matched: Berkshire Hathaway to Berkshire Hathaway(2014 #4)
# Could not be matched: Apple(2014 #5)
# Matched: Phillips 66 to Phillips 66(2014 #6)
# Matched: General Motors to General Motors(2014 #7)
# Matched: Ford Motor to Ford Motor(2014 #8)
# Matched: General Electric to General Electric(2014 #9)
# Matched: Valero Energy to Valero Energy(2014 #10)
# Could not be matched: AT&T(2014 #11)
# Could not be matched: CVS Caremark(2014 #12)
# Could not be matched: Fannie Mae(2014 #13)
# Matched: UnitedHealth Group to United Health Group Inc.(2014 #14)
# Matched: McKesson to McKesson Corp.(2014 #15)
# Matched: Verizon Communications to Verizon Communications(2014 #16)
# Could not be matched: Hewlett-Packard(2014 #17)
# Matched: J.P. Morgan Chase & Co. to JPMorgan Chase & Co.(2014 #18)
# Could not be matched: New York Life Insurance(2018 #69)
# Matched: Goldman Sachs Group to Goldman Sachs Group(2018 #70)
# Matched: American Airlines Group to American Airlines Group(2018 #71)
# Could not be matched: Best Buy(2018 #72)
# Could not be matched: Cigna(2018 #73)
# Matched: Charter Communications to Charter Communications(2018 #74)
# Matched: Delta Air Lines to Delta Air Lines Inc.(2018 #75)
# Matched: Facebook to Facebook, Inc.(2018 #76)
# Matched: Honeywell International to Mondelez International(2018 #77)
# Could not be matched: Merck(2018 #78)
# Matched: Allstate to Allstate Corp(2018 #79)
# Matched: Tyson Foods to Tyson Foods(2018 #80)
# Matched: United Continental Holdings to United Airlines Holdings(2018 #81)
# Could not be matched: Oracle(2018 #82)
# Could not be matched: Tech Data(2018 #83)
# Could not be matched: TIAA(2018 #84)
# Could not be matched: TJX(2018 #85)
# Matched: American Express to American Express Co(2018 #86)
# Could not be matched: Coca-Cola(2018 #87)
# Could not be matched: Publix Super Markets(2018 #88)
# Matched: Nike to Nike(2018 #89)
# Could not be matched: Andeavor(2018 #90)
# Could not be matched: World Fuel Services(2018 #91)
# Could not be matched: Exelon(2018 #92)
# Could not be matched: Massachusetts Mutual Life Insurance(2018 #93)
# Could not be matched: Rite Aid(2018 #94)
# Matched: ConocoPhillips to ConocoPhillips(2018 #95)
# Could not be matched: CHS(2018 #96)
# Could not be matched: 3M(2018 #97)
# Could not be matched: Time Warner(2018 #98)
# Matched: General Dynamics to General Dynamics(2018 #99)
# Could not be matched: USAA(2018 #100)
#      #1 Revenue       #1 Company #1 isTech #1 State #2 Revenue  \
# year
# 2011     479457  Wal-Mart Stores      None     None     403109
# 2012     504341      Exxon Mobil     False       TX     497687
# 2013     514878  Wal-Mart Stores      None     None     493724
# 2014     514362  Wal-Mart Stores      None     None     440248
# 2015     523845          Walmart     False       AR     412686
# 2016     513568          Walmart     False       AR     262258
# 2017     506759          Walmart     False       AR     233216
# 2018     509409          Walmart     False       AR     248791
#
#               #2 Company #2 isTech #2 State #3 Revenue          #3 Company  \
# year
# 2011         Exxon Mobil     False       TX     223149             Chevron
# 2012     Wal-Mart Stores      None     None     273503             Chevron
# 2013         Exxon Mobil     False       TX     256691             Chevron
# 2014         Exxon Mobil     False       TX     237968             Chevron
# 2015         Exxon Mobil     False       TX     219810             Chevron
# 2016         Exxon Mobil     False       TX     248955               Apple
# 2017  Berkshire Hathaway     False       NE     224909               Apple
# 2018         Exxon Mobil     False       TX     246524  Berkshire Hathaway
#
#       ... #98 isTech #98 State #99 Revenue                   #99 Company  \
# year  ...
# 2011  ...       None      None       29429  Plains All American Pipeline
# 2012  ...       None      None     34627.1   Philip Morris International
# 2013  ...      False        VA     34434.5   Philip Morris International
# 2014  ...       None      None     33713.1              General Dynamics
# 2015  ...       None      None     33651.5                Sears Holdings
# 2016  ...       None      None     29951.5                   Time Warner
# 2017  ...      False        CA     28812.5                Travelers Cos.
# 2018  ...       None      None     31534.2              General Dynamics
#
#      #99 isTech #99 State #100 Revenue                 #100 Company  \
# year
# 2011       None      None      29174.5                     Rite Aid
# 2012      False        NY      34182.5                   Nationwide
# 2013      False        NY      33314.3                   Nationwide
# 2014      False        VA        33712  Philip Morris International
# 2015      False        NY      33278.3             General Dynamics
# 2016       None      None        29944          Northwestern Mutual
# 2017       None      None        28702        Capital One Financial
# 2018      False        VA      30559.7                         USAA
#
#      #100 isTech #100 State
# year
# 2011        None       None
# 2012        None       None
# 2013        None       None
# 2014       False         NY
# 2015       False         VA
# 2016        None       None
# 2017       False         VA
# 2018        None       None
#
# [8 rows x 400 columns]

# %%
#inflateDF(df_raw_revenue, start_year, end_year, top_x_companies)
#df_raw_revenue.to_csv('inflated_revenue_1980-2018.csv')
#df_raw_revenue.to_csv('cleaned_revenue_1980-2018.csv')
df_raw_revenue.to_csv('cleaned_revenue_top_ ' + csv_suffix)
df_raw_revenue
# Out:
#      #1 Revenue       #1 Company #1 isTech #1 State #2 Revenue  \
# year
# 2011     479457  Wal-Mart Stores      None     None     403109
# 2012     504341      Exxon Mobil     False       TX     497687
# 2013     514878  Wal-Mart Stores      None     None     493724
# 2014     514362  Wal-Mart Stores      None     None     440248
# 2015     523845          Walmart     False       AR     412686
# 2016     513568          Walmart     False       AR     262258
# 2017     506759          Walmart     False       AR     233216
# 2018     509409          Walmart     False       AR     248791
#
#               #2 Company #2 isTech #2 State #3 Revenue          #3 Company  \
# year
# 2011         Exxon Mobil     False       TX     223149             Chevron
# 2012     Wal-Mart Stores      None     None     273503             Chevron
# 2013         Exxon Mobil     False       TX     256691             Chevron
# 2014         Exxon Mobil     False       TX     237968             Chevron
# 2015         Exxon Mobil     False       TX     219810             Chevron
# 2016         Exxon Mobil     False       TX     248955               Apple
# 2017  Berkshire Hathaway     False       NE     224909               Apple
# 2018         Exxon Mobil     False       TX     246524  Berkshire Hathaway
#
#       ... #98 isTech #98 State #99 Revenue                   #99 Company  \
# year  ...
# 2011  ...       None      None       29429  Plains All American Pipeline
# 2012  ...       None      None     34627.1   Philip Morris International
# 2013  ...      False        VA     34434.5   Philip Morris International
# 2014  ...       None      None     33713.1              General Dynamics
# 2015  ...       None      None     33651.5                Sears Holdings
# 2016  ...       None      None     29951.5                   Time Warner
# 2017  ...      False        CA     28812.5                Travelers Cos.
# 2018  ...       None      None     31534.2              General Dynamics
#
#      #99 isTech #99 State #100 Revenue                 #100 Company  \
# year
# 2011       None      None      29174.5                     Rite Aid
# 2012      False        NY      34182.5                   Nationwide
# 2013      False        NY      33314.3                   Nationwide
# 2014      False        VA        33712  Philip Morris International
# 2015      False        NY      33278.3             General Dynamics
# 2016       None      None        29944          Northwestern Mutual
# 2017       None      None        28702        Capital One Financial
# 2018      False        VA      30559.7                         USAA
#
#      #100 isTech #100 State
# year
# 2011        None       None
# 2012        None       None
# 2013        None       None
# 2014       False         NY
# 2015       False         VA
# 2016        None       None
# 2017       False         VA
# 2018        None       None
#
# [8 rows x 400 columns]

# %%
calculateMeansForDF(df_raw_revenue, start_year, end_year)
df_raw_revenue.to_csv('full_mean_revenue_top_ ' + csv_suffix)
# 2015                                       25717.156739
# 2016                                       24086.771651
# 2017                                       23539.889452
# 2018                                       24408.069930
#
# [9 rows x 502 columns]

# %%
df_raw_revenue = df_raw_revenue[['Mean Revenue Information Technology ($ millions)', 'Mean Revenue Not Information Technology ($ millions)' ]]
df_raw_revenue
# Out:
#       Mean Revenue Information Technology ($ millions)  \
# year
# 2010                                       1233.635772
# 2011                                       1428.535698
# 2012                                       1611.094751
# 2013                                       1681.570455
# 2014                                       1684.600103
# 2015                                       1298.989574
# 2016                                       1467.594552
# 2017                                       1608.352872
# 2018                                       1685.272675
#
#       Mean Revenue Not Information Technology ($ millions)
# year
# 2010                                       21660.498993
# 2011                                       23085.704465
# 2012                                       24557.143079
# 2013                                       24794.080012
# 2014                                       24688.241927
# 2015                                       25717.156739
# 2016                                       24086.771651
# 2017                                       23539.889452
# 2018                                       24408.069930

# %%
#df_raw_revenue.to_csv('final_mean_revenue_1980-2018.csv')

# %%
#table=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
#df_company_info = table[0]
#df_company_info.to_csv('S&P500-Info.csv')
#df_company_info = df_company_info[['Symbol','Security', 'GICS Sector', 'GICS Sub Industry']]
#df_company_info.to_csv('S&P500-Condensed.csv')
#df_company_info

#url = "https://fortune.com/fortune500/2014/apple/"
#page = requests.get(url)
#soup = BeautifulSoup(page.content, "html.parser")
#container = soup.body.table.findAll("td", {"class": "dataTable__value--3n5tL dataTable__valueAlignLeft--3uvNx"})
#print(container[2].div.string)
#print(getCompanySector("walmart", "2019"))

#url = "https://fortune.com/fortune500/2018/search/"
#page = requests.get(url)
#soup = BeautifulSoup(page.content, "html.parser")
#container = soup.findAll("div", {"class": "rt-tr-group"})
#soup.find("div", {"class": "searchWrapper__content--3nwCz"})
#print(container[2].div.string)

# %%
company_info = pd.read_csv('S&P500-Info.csv')
company_info = company_info[['Symbol', 'Security', 'GICS Sector', 'GICS Sub Industry', 'Headquarters Location']]
company_info
# Out:
#     Symbol                Security             GICS Sector  \
# 0      MMM              3M Company             Industrials
# 1      ABT     Abbott Laboratories             Health Care
# 2     ABBV             AbbVie Inc.             Health Care
# 3     ABMD             ABIOMED Inc             Health Care
# 4      ACN           Accenture plc  Information Technology
# ..     ...                     ...                     ...
# 500    YUM         Yum! Brands Inc  Consumer Discretionary
# 501   ZBRA      Zebra Technologies  Information Technology
# 502    ZBH  Zimmer Biomet Holdings             Health Care
# 503   ZION           Zions Bancorp              Financials
# 504    ZTS                  Zoetis             Health Care
#
#                       GICS Sub Industry     Headquarters Location
# 0              Industrial Conglomerates       St. Paul, Minnesota
# 1                 Health Care Equipment   North Chicago, Illinois
# 2                       Pharmaceuticals   North Chicago, Illinois
# 3                 Health Care Equipment    Danvers, Massachusetts
# 4        IT Consulting & Other Services           Dublin, Ireland
# ..                                  ...                       ...
# 500                         Restaurants      Louisville, Kentucky
# 501  Electronic Equipment & Instruments    Lincolnshire, Illinois
# 502               Health Care Equipment           Warsaw, Indiana
# 503                      Regional Banks      Salt Lake City, Utah
# 504                     Pharmaceuticals  Florham Park, New Jersey
#
# [505 rows x 5 columns]
